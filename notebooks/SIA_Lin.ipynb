# %% [markdown]
# # Utilização da Função para Conversão de dados do DataSUS

# %% [markdown]
# A conversão dos arquivos desse notebook é feito a partir da função ParquetSet do PySUS
#
# O PySUS até o momento só pode ser instalado em Sistemas Linux, logo, a utilização da função de conversão 'ParquetSet' só ocorre em Linux
#
# No caso do Sistema Operacional da sua máquina não ser Linux, você pode utilizar o WSL (Windows Subsystem for Linux) que traduz Syscall do Linux para o Kernel do Windows

# %% [markdown]
# Garantir importação correta

# %%
import sys
import os

# Caminho absoluto até a pasta src
SRC_PATH = os.path.abspath("../src")

# Adiciona ao PYTHONPATH
if SRC_PATH not in sys.path:
    sys.path.append(SRC_PATH)

# %% [markdown]
# Importação da Bibioteca de funções para SIA no Linux

# %%
import fun_sia_linux as fsl

import importlib
importlib.reload(fsl)
# Out:
# <module 'fun_sia_linux' from '/mnt/c/Users/guilh/OneDrive/Desktop/Projetos/Projeto_Bolsa/src/fun_sia_linux.py'>

# %% [markdown]
# Conversão dos arquivos .dbc para .parquet

# %%
fsl.conv_dbc_para_pqt(pasta_origem = "../dados_sia/dados_dbc", pasta_destino = "../dados_sia/dados_parquet")
# Out:
# Convertendo: ../dados_sia/dados_dbc/PACE2105.dbc
# PACE2105 convertido (vários arquivos .parquet)
# Convertendo: ../dados_sia/dados_dbc/PACE2106.dbc
# PACE2106 convertido (vários arquivos .parquet)
